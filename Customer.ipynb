# %%
import requests
import pandas as pd
import time
import random
from tqdm import tqdm

cookies = {
    'TIKI_GUEST_TOKEN': '8jWSuIDBb2NGVzr6hsUZXpkP1FRin7lY',
    'TOKENS': '{%22access_token%22:%228jWSuIDBb2NGVzr6hsUZXpkP1FRin7lY%22%2C%22expires_in%22:157680000%2C%22expires_at%22:1763654224277%2C%22guest_token%22:%228jWSuIDBb2NGVzr6hsUZXpkP1FRin7lY%22}',
    'amp_99d374': 'eSc-_0HT1um7cb57E7dwA0...1enloc6a2.1enlrj4bc.1k.11.2l',
    'amp_99d374_tiki.vn': 'eSc-_0HT1um7cb57E7dwA0...1enloc6a2.1enlrj2q9.3.1.1',
    '_gcl_au': '1.1.559117409.1605974236',
    '_ants_utm_v2': '',
    '_pk_id.638735871.2fc5': 'b92ae025fbbdb31f.1605974236.1.1605977607.1605974236.',
    '_pk_ses.638735871.2fc5': '*',
    '_trackity': '70e316b0-96f2-dbe1-a2ed-43ff60419991',
    '_ga_NKX31X43RV': 'GS1.1.1605974235.1.1.1605977607.0',
    '_ga': 'GA1.2.657946765.1605974236',
    'ai_client_id': '11935756853.1605974227',
    'an_session': 'zizkzrzjzkzizhzkzlznzdzizizqzgzmzkzmzlzrzmzgzdzizlzjzmzqzkzlzjzgzjzdzizizdzizlzjzmzqzkzlzjzgzjzdzizlzjzmzqzkzlzjzgzjzdzjzdzhzqzdzizd2f27zdzjzdzlzmzmznzq',
    'au_aid': '11935756853',
    'dgs': '1605977598%3A3%3A0',
    'au_gt': '1605974227146',
    '_ants_services': '%5B%22cuid%22%5D',
    '__admUTMtime': '1605974236',
    '__iid': '749',
    '__su': '0',
    '_bs': 'bb9a32f6-ab13-ce80-92d6-57fd3fd6e4c8',
    '_gid': 'GA1.2.867846791.1605974237',
    '_fbp': 'fb.1.1605974237134.1297408816',
    '_hjid': 'f152cf33-7323-4410-b9ae-79f6622ebc48',
    '_hjFirstSeen': '1',
    '_hjAbsoluteSessionInProgress': '0',
    'tiki_client_id': '657946765.1605974236',
    '__gads': 'ID=ae56424189ecccbe-227eb8e1d6c400a8:T=1605974229:RT=1605974229:S=ALNI_MZFWYf2BAjzCSiRNLC3bKI-W_7YHA',
    'proxy_s_sv': '1605978058486',
    'TKSESSID': '8bcd49b02e1e16aa1cdb795c54d7b460',
    'TIKI_RECOMMENDATION': '21dd50e7f7c194df673ea3b717459249',
    'cto_bundle': '7L6ha19NVXNkQmJ6aEVLcXNqbHdjcVZoQ0kzTUZwcEMyNCUyRm5nV3A2SThuOGxTRjI4Wlk1NU9xRnBEOG9tUjd2ekhyZEQxeE9qaVQ4MnFpbiUyRllGd2JiQUpTMW94MlNsTnYxd3dOYWtRcXhGdDNxSjdBVmNxU0FnUSUyQjlWYjhqTUtLdVl2cTBheWFvS0ZnY2pLdlpWRlEyUFF0Y1ElM0QlM0Q',
    'TIKI_RECENTLYVIEWED': '58259141',
    '_ants_event_his': '%7B%22action%22%3A%22view%22%2C%22time%22%3A1605977607258%7D',
    '_hjIncludedInPageviewSample': '1',
    '_hjIncludedInSessionSample': '1',
    '_gat': '1',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36',
    'Accept': 'application/json, text/plain, /',
    'Accept-Language': 'en-US;q=0.5,en;q=0.3',
    'Referer': 'https://tiki.vn/sua-rua-mat-simple-giup-kiem-dau-ngua-mun-cho-da-mun-nhay-cam-khong-chua-xa-phong-150ml-chinh-hang-doc-quyen-p117170051.html?itm_campaign=SRC_YPD_TKA_PLA_UNK_ALL_UNK_UNK_UNK_UNK_X.173132_Y.1755459_Z.3365632_CN.Skin_Product_FW_Simple&itm_medium=CPC&itm_source=tiki-ads&spid=117170052',
    'X-Guest-Token': 'ruNHK0vfxczpXV35yZAaMnQ7s2qk9JBT',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
    'page': '1',
    'sort': 'score|desc,id|desc,stars|all',
    'spid': '117170052',
    'product_id': '117170051',
    'seller_id': '1',
    'limit': '5',
    'include': 'comments,contribute_info,attribute_vote_summary'

}

def comment_parser(json_data, pid, stars_dict):
    d = dict()
    d['pid'] = pid
    created_by = json_data.get('created_by')
    if created_by:
        d['customer_name'] = created_by.get('name')
        if json_data.get('created_by').get('contribute_info'):
            d['customer_id'] = json_data.get('created_by').get('contribute_info').get('id')
            summary = json_data.get('created_by').get('contribute_info')
            if summary:
                d['joined_time'] = json_data.get('created_by').get('contribute_info').get('summary').get('joined_time')
                d['total_review'] = json_data.get('created_by').get('contribute_info').get('summary').get('total_review')
                d['total_thank'] = json_data.get('created_by').get('contribute_info').get('summary').get('total_thank')
            else:
                d['joined_time'] = None
                d['total_review'] = None
                d['total_thank'] = None
        else:
            d['customer_id'] = None
    else:
        d['purchased_at'] = None
    return d

df_id = pd.read_csv('product_id_ncds.csv')
p_ids = df_id.id.to_list()
print(p_ids)
result = []
Err = []

for pid in tqdm(p_ids, total=len(p_ids)):
    params['product_id'] = pid
    print('Crawl comment for product {}'.format(pid))
    page = 0
    response_1 = requests.get('https://tiki.vn/api/v2/reviews', headers=headers, params=params, cookies=cookies)
    if response_1.status_code == 200:
        temp = response_1.json().get('stars')
        
        
    while True:  # This will loop until there's no more data
        params['page'] = page
        response = requests.get('https://tiki.vn/api/v2/reviews', headers=headers, params=params, cookies=cookies)
        if response.status_code == 200:
            data = response.json().get('data')
            if not data:  # if data is empty, break out of the loop
                break
            print('Crawl comment page {} success!!!'.format(page))
            for comment in data:
                result.append(comment_parser(comment,pid,temp))
            page += 1
        else:
            break
customer = pd.DataFrame(result)
#df_comment.to_csv('comments_data_ncds_500_1000.csv', index=False)

# %%
customer = pd.DataFrame(result)
customer.to_csv('Data_Cleaned\customer.csv')

# %%
customer.drop_duplicates().reset_index().to_csv('Data_Cleaned\customer.csv')

# %%
customer = pd.read_csv('Data_Cleaned\customer.csv')

# %%
customer.drop(['Unnamed: 0','index'], axis = 1, inplace = True)

# %%
customer
# Out:
#             pid         customer_name  customer_id         joined_time  \
# 0        631525  Lê Nguyễn Ngọc Tuyền   11193658.0   Đã tham gia 5 năm
# 1        631525              Thu Thảo   22593905.0   Đã tham gia 2 năm
# 2        631525     Phan Van Anh Quoc    5253627.0   Đã tham gia 7 năm
# 3        631525          Trần Gia Lộc    1975356.0   Đã tham gia 7 năm
# 4        631525             Loãn Loãn   24090978.0   Đã tham gia 2 năm
# ...         ...                   ...          ...                 ...
# 15149  10863625             Tams Pham    7836571.0   Đã tham gia 5 năm
# 15150  16749502          Nguyễn Duyên    9896555.0   Đã tham gia 5 năm
# 15151  29358683             Dương Như      78323.0  Đã tham gia 11 năm
# 15152  29358683           Phương Linh   19327044.0   Đã tham gia 3 năm
# 15153  29358683        Đào Linh Trang      12298.0  Đã tham gia 12 năm
#
#        total_review  total_thank  purchased_at
# 0              21.0          4.0           NaN
# 1              35.0          0.0           NaN
# 2              14.0         48.0           NaN
# 3              21.0         15.0           NaN
# 4              15.0         12.0           NaN
# ...             ...          ...           ...
# 15149          36.0         11.0           NaN
# 15150           2.0          0.0           NaN
# 15151          27.0          4.0           NaN
# 15152           1.0          0.0           NaN
# 15153          74.0          8.0           NaN
#
# [15154 rows x 7 columns]

# %%
comment = pd.read_csv('comments.csv')
customer = pd.read_csv('Data_Cleaned\customer.csv')

# %%
temp = pd.merge(comment,customer, left_on='customer_id', right_on='customer_id', how = 'left')
temp = temp.drop_duplicates()

# %%
temp
# Out:
#           pid_x        id  customer_id            title       purchased_at_x  \
# 0        631525  16969600     22593905  Cực kì hài lòng  2022-07-06 15:43:00
# 1        631525  16969600     22593905  Cực kì hài lòng  2022-07-06 15:43:00
# 2        631525   2410732      1975356  Cực kì hài lòng  2019-08-24 12:52:00
# 3        631525  15187820     24090978  Cực kì hài lòng  2022-02-03 12:02:33
# 4        631525  18198813      7298595  Cực kì hài lòng  2022-11-11 05:45:36
# ...         ...       ...          ...              ...                  ...
# 17081  10863625   2531934      7836571      Bình thường  2019-10-15 22:50:27
# 17082  16749502   3788489      9896555  Cực kì hài lòng  2020-05-20 12:03:11
# 17083  29358683   7020037        78323  Cực kì hài lòng  2021-01-13 09:27:45
# 17084  29358683   8958317     19327044  Cực kì hài lòng  2021-04-05 12:38:22
# 17085  29358683   5382828        12298  Cực kì hài lòng  2020-10-16 23:18:01
#
#                 created_at                                            content  \
# 0      2022-07-07 10:17:40  Đặt 2 món chung 1 đơn hàng để được khuyến thêm...
# 1      2022-07-07 10:17:40  Đặt 2 món chung 1 đơn hàng để được khuyến thêm...
# 2      2019-08-27 11:21:22  Tiki có thù với vỏ niêm phong hay gì, sao lần ...
# 3      2022-02-28 15:04:45        Hada Labo Pro Anti Aging α Lifting Cleanser
# 4      2022-11-13 21:11:49  Oke. Ít bọt. Chất kem đặc. Tác dụng chống lão ...
# ...                    ...                                                ...
# 17081  2019-10-17 23:23:59  da mình hỗn hợp thiên khô, lúc mới rửa bọt nhi...
# 17082  2020-06-12 13:37:34                                                NaN
# 17083  2021-01-17 10:05:31  mua cho bé bị viêm da do tiết bã xài 2 lần sau...
# 17084  2021-04-07 23:05:46                                                NaN
# 17085  2020-10-28 10:12:55                                                 Ổn
#
#        thank_count  rating  Unnamed: 0    index       pid_y  \
# 0                0       5         1.0      1.0    631525.0
# 1                0       5     13014.0  15376.0   2406967.0
# 2                5       5         3.0      3.0    631525.0
# 3                0       5         4.0      4.0    631525.0
# 4                0       5         5.0     10.0    631525.0
# ...            ...     ...         ...      ...         ...
# 17081            0       3     15149.0  18227.0  10863625.0
# 17082            0       5     15150.0  18229.0  16749502.0
# 17083            0       5     15151.0  18231.0  29358683.0
# 17084            0       5     15152.0  18232.0  29358683.0
# 17085            0       5     15153.0  18233.0  29358683.0
#
#             customer_name         joined_time  total_review  total_thank  \
# 0                Thu Thảo   Đã tham gia 2 năm          35.0          0.0
# 1                Thu Thảo   Đã tham gia 2 năm          35.0          0.0
# 2            Trần Gia Lộc   Đã tham gia 7 năm          21.0         15.0
# 3               Loãn Loãn   Đã tham gia 2 năm          15.0         12.0
# 4      HUỲNH THỊ CẨM LOAN   Đã tham gia 6 năm         163.0         80.0
# ...                   ...                 ...           ...          ...
# 17081           Tams Pham   Đã tham gia 5 năm          36.0         11.0
# 17082        Nguyễn Duyên   Đã tham gia 5 năm           2.0          0.0
# 17083           Dương Như  Đã tham gia 11 năm          27.0          4.0
# 17084         Phương Linh   Đã tham gia 3 năm           1.0          0.0
# 17085      Đào Linh Trang  Đã tham gia 12 năm          74.0          8.0
#
#        purchased_at_y
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 17081             NaN
# 17082             NaN
# 17083             NaN
# 17084             NaN
# 17085             NaN
#
# [17086 rows x 17 columns]

# %%
customer = customer.drop(['pid','purchased_at'], axis = 1)
customer
# Out:
#               customer_name  customer_id         joined_time  total_review  \
# 0      Lê Nguyễn Ngọc Tuyền   11193658.0   Đã tham gia 5 năm          21.0
# 1                  Thu Thảo   22593905.0   Đã tham gia 2 năm          35.0
# 2         Phan Van Anh Quoc    5253627.0   Đã tham gia 7 năm          14.0
# 3              Trần Gia Lộc    1975356.0   Đã tham gia 7 năm          21.0
# 4                 Loãn Loãn   24090978.0   Đã tham gia 2 năm          15.0
# ...                     ...          ...                 ...           ...
# 15149             Tams Pham    7836571.0   Đã tham gia 5 năm          36.0
# 15150          Nguyễn Duyên    9896555.0   Đã tham gia 5 năm           2.0
# 15151             Dương Như      78323.0  Đã tham gia 11 năm          27.0
# 15152           Phương Linh   19327044.0   Đã tham gia 3 năm           1.0
# 15153        Đào Linh Trang      12298.0  Đã tham gia 12 năm          74.0
#
#        total_thank
# 0              4.0
# 1              0.0
# 2             48.0
# 3             15.0
# 4             12.0
# ...            ...
# 15149         11.0
# 15150          0.0
# 15151          4.0
# 15152          0.0
# 15153          8.0
#
# [15154 rows x 5 columns]

# %%
comment
# Out:
#             pid        id  customer_id            title         purchased_at  \
# 0        631525  16969600     22593905  Cực kì hài lòng  2022-07-06 15:43:00
# 1        631525   2410732      1975356  Cực kì hài lòng  2019-08-24 12:52:00
# 2        631525  15187820     24090978  Cực kì hài lòng  2022-02-03 12:02:33
# 3        631525  18198813      7298595  Cực kì hài lòng  2022-11-11 05:45:36
# 4        631525  18523163     11321006  Cực kì hài lòng  2022-12-27 11:34:36
# ...         ...       ...          ...              ...                  ...
# 14937  10863625   2531934      7836571      Bình thường  2019-10-15 22:50:27
# 14938  16749502   3788489      9896555  Cực kì hài lòng  2020-05-20 12:03:11
# 14939  29358683   7020037        78323  Cực kì hài lòng  2021-01-13 09:27:45
# 14940  29358683   8958317     19327044  Cực kì hài lòng  2021-04-05 12:38:22
# 14941  29358683   5382828        12298  Cực kì hài lòng  2020-10-16 23:18:01
#
#                 created_at                                            content  \
# 0      2022-07-07 10:17:40  Đặt 2 món chung 1 đơn hàng để được khuyến thêm...
# 1      2019-08-27 11:21:22  Tiki có thù với vỏ niêm phong hay gì, sao lần ...
# 2      2022-02-28 15:04:45        Hada Labo Pro Anti Aging α Lifting Cleanser
# 3      2022-11-13 21:11:49  Oke. Ít bọt. Chất kem đặc. Tác dụng chống lão ...
# 4      2022-12-28 11:56:04  Sản phẩm không có vấn đề gì ngoại trừ nắp khôn...
# ...                    ...                                                ...
# 14937  2019-10-17 23:23:59  da mình hỗn hợp thiên khô, lúc mới rửa bọt nhi...
# 14938  2020-06-12 13:37:34                                                NaN
# 14939  2021-01-17 10:05:31  mua cho bé bị viêm da do tiết bã xài 2 lần sau...
# 14940  2021-04-07 23:05:46                                                NaN
# 14941  2020-10-28 10:12:55                                                 Ổn
#
#        thank_count  rating
# 0                0       5
# 1                5       5
# 2                0       5
# 3                0       5
# 4                0       5
# ...            ...     ...
# 14937            0       3
# 14938            0       5
# 14939            0       5
# 14940            0       5
# 14941            0       5
#
# [14942 rows x 9 columns]

# %%
comment
# Out:
#             pid        id  customer_id            title         purchased_at  \
# 0        631525  16969600     22593905  Cực kì hài lòng  2022-07-06 15:43:00
# 1        631525   2410732      1975356  Cực kì hài lòng  2019-08-24 12:52:00
# 2        631525  15187820     24090978  Cực kì hài lòng  2022-02-03 12:02:33
# 3        631525  18198813      7298595  Cực kì hài lòng  2022-11-11 05:45:36
# 4        631525  18523163     11321006  Cực kì hài lòng  2022-12-27 11:34:36
# ...         ...       ...          ...              ...                  ...
# 14937  10863625   2531934      7836571      Bình thường  2019-10-15 22:50:27
# 14938  16749502   3788489      9896555  Cực kì hài lòng  2020-05-20 12:03:11
# 14939  29358683   7020037        78323  Cực kì hài lòng  2021-01-13 09:27:45
# 14940  29358683   8958317     19327044  Cực kì hài lòng  2021-04-05 12:38:22
# 14941  29358683   5382828        12298  Cực kì hài lòng  2020-10-16 23:18:01
#
#                 created_at                                            content  \
# 0      2022-07-07 10:17:40  Đặt 2 món chung 1 đơn hàng để được khuyến thêm...
# 1      2019-08-27 11:21:22  Tiki có thù với vỏ niêm phong hay gì, sao lần ...
# 2      2022-02-28 15:04:45        Hada Labo Pro Anti Aging α Lifting Cleanser
# 3      2022-11-13 21:11:49  Oke. Ít bọt. Chất kem đặc. Tác dụng chống lão ...
# 4      2022-12-28 11:56:04  Sản phẩm không có vấn đề gì ngoại trừ nắp khôn...
# ...                    ...                                                ...
# 14937  2019-10-17 23:23:59  da mình hỗn hợp thiên khô, lúc mới rửa bọt nhi...
# 14938  2020-06-12 13:37:34                                                NaN
# 14939  2021-01-17 10:05:31  mua cho bé bị viêm da do tiết bã xài 2 lần sau...
# 14940  2021-04-07 23:05:46                                                NaN
# 14941  2020-10-28 10:12:55                                                 Ổn
#
#        thank_count  rating
# 0                0       5
# 1                5       5
# 2                0       5
# 3                0       5
# 4                0       5
# ...            ...     ...
# 14937            0       3
# 14938            0       5
# 14939            0       5
# 14940            0       5
# 14941            0       5
#
# [14942 rows x 9 columns]

# %%
temp = pd.merge(comment,customer, left_on='customer_id',right_on='customer_id', how = 'left')
temp.drop_duplicates(inplace = True)

# %%
temp
# Out:
#             pid        id  customer_id            title         purchased_at  \
# 0        631525  16969600     22593905  Cực kì hài lòng  2022-07-06 15:43:00
# 2        631525   2410732      1975356  Cực kì hài lòng  2019-08-24 12:52:00
# 3        631525  15187820     24090978  Cực kì hài lòng  2022-02-03 12:02:33
# 4        631525  18198813      7298595  Cực kì hài lòng  2022-11-11 05:45:36
# 5        631525  18523163     11321006  Cực kì hài lòng  2022-12-27 11:34:36
# ...         ...       ...          ...              ...                  ...
# 17081  10863625   2531934      7836571      Bình thường  2019-10-15 22:50:27
# 17082  16749502   3788489      9896555  Cực kì hài lòng  2020-05-20 12:03:11
# 17083  29358683   7020037        78323  Cực kì hài lòng  2021-01-13 09:27:45
# 17084  29358683   8958317     19327044  Cực kì hài lòng  2021-04-05 12:38:22
# 17085  29358683   5382828        12298  Cực kì hài lòng  2020-10-16 23:18:01
#
#                 created_at                                            content  \
# 0      2022-07-07 10:17:40  Đặt 2 món chung 1 đơn hàng để được khuyến thêm...
# 2      2019-08-27 11:21:22  Tiki có thù với vỏ niêm phong hay gì, sao lần ...
# 3      2022-02-28 15:04:45        Hada Labo Pro Anti Aging α Lifting Cleanser
# 4      2022-11-13 21:11:49  Oke. Ít bọt. Chất kem đặc. Tác dụng chống lão ...
# 5      2022-12-28 11:56:04  Sản phẩm không có vấn đề gì ngoại trừ nắp khôn...
# ...                    ...                                                ...
# 17081  2019-10-17 23:23:59  da mình hỗn hợp thiên khô, lúc mới rửa bọt nhi...
# 17082  2020-06-12 13:37:34                                                NaN
# 17083  2021-01-17 10:05:31  mua cho bé bị viêm da do tiết bã xài 2 lần sau...
# 17084  2021-04-07 23:05:46                                                NaN
# 17085  2020-10-28 10:12:55                                                 Ổn
#
#        thank_count  rating       customer_name         joined_time  \
# 0                0       5            Thu Thảo   Đã tham gia 2 năm
# 2                5       5        Trần Gia Lộc   Đã tham gia 7 năm
# 3                0       5           Loãn Loãn   Đã tham gia 2 năm
# 4                0       5  HUỲNH THỊ CẨM LOAN   Đã tham gia 6 năm
# 5                0       5        Nguyễn Duyên   Đã tham gia 5 năm
# ...            ...     ...                 ...                 ...
# 17081            0       3           Tams Pham   Đã tham gia 5 năm
# 17082            0       5        Nguyễn Duyên   Đã tham gia 5 năm
# 17083            0       5           Dương Như  Đã tham gia 11 năm
# 17084            0       5         Phương Linh   Đã tham gia 3 năm
# 17085            0       5      Đào Linh Trang  Đã tham gia 12 năm
#
#        total_review  total_thank
# 0              35.0          0.0
# 2              21.0         15.0
# 3              15.0         12.0
# 4             163.0         80.0
# 5              75.0          2.0
# ...             ...          ...
# 17081          36.0         11.0
# 17082           2.0          0.0
# 17083          27.0          4.0
# 17084           1.0          0.0
# 17085          74.0          8.0
#
# [14990 rows x 13 columns]

# %%
temp = temp.reset_index(drop = True)

# %%
temp.drop('index', axis = 1, inplace=True)

# %%
temp
# Out:
#             pid        id  customer_id            title         purchased_at  \
# 0        631525  16969600     22593905  Cực kì hài lòng  2022-07-06 15:43:00
# 1        631525   2410732      1975356  Cực kì hài lòng  2019-08-24 12:52:00
# 2        631525  15187820     24090978  Cực kì hài lòng  2022-02-03 12:02:33
# 3        631525  18198813      7298595  Cực kì hài lòng  2022-11-11 05:45:36
# 4        631525  18523163     11321006  Cực kì hài lòng  2022-12-27 11:34:36
# ...         ...       ...          ...              ...                  ...
# 14985  10863625   2531934      7836571      Bình thường  2019-10-15 22:50:27
# 14986  16749502   3788489      9896555  Cực kì hài lòng  2020-05-20 12:03:11
# 14987  29358683   7020037        78323  Cực kì hài lòng  2021-01-13 09:27:45
# 14988  29358683   8958317     19327044  Cực kì hài lòng  2021-04-05 12:38:22
# 14989  29358683   5382828        12298  Cực kì hài lòng  2020-10-16 23:18:01
#
#                 created_at                                            content  \
# 0      2022-07-07 10:17:40  Đặt 2 món chung 1 đơn hàng để được khuyến thêm...
# 1      2019-08-27 11:21:22  Tiki có thù với vỏ niêm phong hay gì, sao lần ...
# 2      2022-02-28 15:04:45        Hada Labo Pro Anti Aging α Lifting Cleanser
# 3      2022-11-13 21:11:49  Oke. Ít bọt. Chất kem đặc. Tác dụng chống lão ...
# 4      2022-12-28 11:56:04  Sản phẩm không có vấn đề gì ngoại trừ nắp khôn...
# ...                    ...                                                ...
# 14985  2019-10-17 23:23:59  da mình hỗn hợp thiên khô, lúc mới rửa bọt nhi...
# 14986  2020-06-12 13:37:34                                                NaN
# 14987  2021-01-17 10:05:31  mua cho bé bị viêm da do tiết bã xài 2 lần sau...
# 14988  2021-04-07 23:05:46                                                NaN
# 14989  2020-10-28 10:12:55                                                 Ổn
#
#        thank_count  rating       customer_name         joined_time  \
# 0                0       5            Thu Thảo   Đã tham gia 2 năm
# 1                5       5        Trần Gia Lộc   Đã tham gia 7 năm
# 2                0       5           Loãn Loãn   Đã tham gia 2 năm
# 3                0       5  HUỲNH THỊ CẨM LOAN   Đã tham gia 6 năm
# 4                0       5        Nguyễn Duyên   Đã tham gia 5 năm
# ...            ...     ...                 ...                 ...
# 14985            0       3           Tams Pham   Đã tham gia 5 năm
# 14986            0       5        Nguyễn Duyên   Đã tham gia 5 năm
# 14987            0       5           Dương Như  Đã tham gia 11 năm
# 14988            0       5         Phương Linh   Đã tham gia 3 năm
# 14989            0       5      Đào Linh Trang  Đã tham gia 12 năm
#
#        total_review  total_thank
# 0              35.0          0.0
# 1              21.0         15.0
# 2              15.0         12.0
# 3             163.0         80.0
# 4              75.0          2.0
# ...             ...          ...
# 14985          36.0         11.0
# 14986           2.0          0.0
# 14987          27.0          4.0
# 14988           1.0          0.0
# 14989          74.0          8.0
#
# [14990 rows x 13 columns]

# %%
comment = temp[['pid','customer_id','id','title','purchased_at','created_at','content','thank_count','rating']]
comment
# Out:
#             pid  customer_id        id            title         purchased_at  \
# 0        631525     22593905  16969600  Cực kì hài lòng  2022-07-06 15:43:00
# 1        631525      1975356   2410732  Cực kì hài lòng  2019-08-24 12:52:00
# 2        631525     24090978  15187820  Cực kì hài lòng  2022-02-03 12:02:33
# 3        631525      7298595  18198813  Cực kì hài lòng  2022-11-11 05:45:36
# 4        631525     11321006  18523163  Cực kì hài lòng  2022-12-27 11:34:36
# ...         ...          ...       ...              ...                  ...
# 14985  10863625      7836571   2531934      Bình thường  2019-10-15 22:50:27
# 14986  16749502      9896555   3788489  Cực kì hài lòng  2020-05-20 12:03:11
# 14987  29358683        78323   7020037  Cực kì hài lòng  2021-01-13 09:27:45
# 14988  29358683     19327044   8958317  Cực kì hài lòng  2021-04-05 12:38:22
# 14989  29358683        12298   5382828  Cực kì hài lòng  2020-10-16 23:18:01
#
#                 created_at                                            content  \
# 0      2022-07-07 10:17:40  Đặt 2 món chung 1 đơn hàng để được khuyến thêm...
# 1      2019-08-27 11:21:22  Tiki có thù với vỏ niêm phong hay gì, sao lần ...
# 2      2022-02-28 15:04:45        Hada Labo Pro Anti Aging α Lifting Cleanser
# 3      2022-11-13 21:11:49  Oke. Ít bọt. Chất kem đặc. Tác dụng chống lão ...
# 4      2022-12-28 11:56:04  Sản phẩm không có vấn đề gì ngoại trừ nắp khôn...
# ...                    ...                                                ...
# 14985  2019-10-17 23:23:59  da mình hỗn hợp thiên khô, lúc mới rửa bọt nhi...
# 14986  2020-06-12 13:37:34                                                NaN
# 14987  2021-01-17 10:05:31  mua cho bé bị viêm da do tiết bã xài 2 lần sau...
# 14988  2021-04-07 23:05:46                                                NaN
# 14989  2020-10-28 10:12:55                                                 Ổn
#
#        thank_count  rating
# 0                0       5
# 1                5       5
# 2                0       5
# 3                0       5
# 4                0       5
# ...            ...     ...
# 14985            0       3
# 14986            0       5
# 14987            0       5
# 14988            0       5
# 14989            0       5
#
# [14990 rows x 9 columns]

# %%
customer = temp[['customer_id','customer_name','joined_time','total_review','total_thank']]
customer
# Out:
#        customer_id       customer_name         joined_time  total_review  \
# 0         22593905            Thu Thảo   Đã tham gia 2 năm          35.0
# 1          1975356        Trần Gia Lộc   Đã tham gia 7 năm          21.0
# 2         24090978           Loãn Loãn   Đã tham gia 2 năm          15.0
# 3          7298595  HUỲNH THỊ CẨM LOAN   Đã tham gia 6 năm         163.0
# 4         11321006        Nguyễn Duyên   Đã tham gia 5 năm          75.0
# ...            ...                 ...                 ...           ...
# 14985      7836571           Tams Pham   Đã tham gia 5 năm          36.0
# 14986      9896555        Nguyễn Duyên   Đã tham gia 5 năm           2.0
# 14987        78323           Dương Như  Đã tham gia 11 năm          27.0
# 14988     19327044         Phương Linh   Đã tham gia 3 năm           1.0
# 14989        12298      Đào Linh Trang  Đã tham gia 12 năm          74.0
#
#        total_thank
# 0              0.0
# 1             15.0
# 2             12.0
# 3             80.0
# 4              2.0
# ...            ...
# 14985         11.0
# 14986          0.0
# 14987          4.0
# 14988          0.0
# 14989          8.0
#
# [14990 rows x 5 columns]

# %%
customer.drop_duplicates()
# Out:
#        customer_id       customer_name         joined_time  total_review  \
# 0         22593905            Thu Thảo   Đã tham gia 2 năm          35.0
# 1          1975356        Trần Gia Lộc   Đã tham gia 7 năm          21.0
# 2         24090978           Loãn Loãn   Đã tham gia 2 năm          15.0
# 3          7298595  HUỲNH THỊ CẨM LOAN   Đã tham gia 6 năm         163.0
# 4         11321006        Nguyễn Duyên   Đã tham gia 5 năm          75.0
# ...            ...                 ...                 ...           ...
# 14985      7836571           Tams Pham   Đã tham gia 5 năm          36.0
# 14986      9896555        Nguyễn Duyên   Đã tham gia 5 năm           2.0
# 14987        78323           Dương Như  Đã tham gia 11 năm          27.0
# 14988     19327044         Phương Linh   Đã tham gia 3 năm           1.0
# 14989        12298      Đào Linh Trang  Đã tham gia 12 năm          74.0
#
#        total_thank
# 0              0.0
# 1             15.0
# 2             12.0
# 3             80.0
# 4              2.0
# ...            ...
# 14985         11.0
# 14986          0.0
# 14987          4.0
# 14988          0.0
# 14989          8.0
#
# [14060 rows x 5 columns]

# %%
customer = customer.drop_duplicates().reset_index()

# %%
customer.drop('index', axis = 1, inplace = True)

# %%
customer
# Out:
#        customer_id       customer_name         joined_time  total_review  \
# 0         22593905            Thu Thảo   Đã tham gia 2 năm          35.0
# 1          1975356        Trần Gia Lộc   Đã tham gia 7 năm          21.0
# 2         24090978           Loãn Loãn   Đã tham gia 2 năm          15.0
# 3          7298595  HUỲNH THỊ CẨM LOAN   Đã tham gia 6 năm         163.0
# 4         11321006        Nguyễn Duyên   Đã tham gia 5 năm          75.0
# ...            ...                 ...                 ...           ...
# 14055      7836571           Tams Pham   Đã tham gia 5 năm          36.0
# 14056      9896555        Nguyễn Duyên   Đã tham gia 5 năm           2.0
# 14057        78323           Dương Như  Đã tham gia 11 năm          27.0
# 14058     19327044         Phương Linh   Đã tham gia 3 năm           1.0
# 14059        12298      Đào Linh Trang  Đã tham gia 12 năm          74.0
#
#        total_thank
# 0              0.0
# 1             15.0
# 2             12.0
# 3             80.0
# 4              2.0
# ...            ...
# 14055         11.0
# 14056          0.0
# 14057          4.0
# 14058          0.0
# 14059          8.0
#
# [14060 rows x 5 columns]

# %%
customer.to_csv('Data_Cleaned\customer.csv')
